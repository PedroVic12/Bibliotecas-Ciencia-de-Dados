# %% [markdown]
# ### Circunferência

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#* Teste 
x =[x for x in range(101)]
y = [y**2 for y in x]

plt.plot(x,y,'-')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
# Out:
# Text(0, 0.5, 'Eixo y')

# %% [markdown]
# Dada a equação da circunferência, faça o gráfico.
#
# $$ (x-a)^2 + (y-b)^2 = r^2  $$
#
# r = 100
#
# a = 100
#
# b = 100

# %%
"""
*Isolando o Y:
! (y-b)^2 = r^2 - (x-a)^2
! y = sqrt(r**2 - (x-a)**2) + b 
"""

from math import sqrt
r,a,b = 100,100,100

x = []
y = []

x = [i for i in range(2*r + 1)] #* 2*r + 1 = 201 → DIAMETRO!

y_x = lambda x: sqrt((r**2)- (x-a)**2) + b

y_x_negativo = lambda x: -sqrt((r**2)- (x-a)**2) + b

y.extend(list(map(y_x,x)))
y.extend(list(map(y_x_negativo,x)))

x.extend(x)

plt.plot(x,y)
